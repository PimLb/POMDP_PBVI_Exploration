# %%
from matplotlib import pyplot as plt
import matplotlib as mpl
import pandas as pd
import numpy as np
import copy
import json

from viz_functions import *

# %% [markdown]
# # Grid test viz

# %%
folder = 'C:/Users/arnau/Desktop/Master Thesis Files [TO BACKUP]/Test_GroundAir_FSVI_300it_100exp_099g_e6eps_20run_20231121_165329'

# %%
grid_test_df = pd.read_csv(folder + '/GridSimulations/Grid-run-0-1560sims.csv')

# %%
grid_test_df
# Out:
#         x   y  cell  cell_x  cell_y  opt_traj  point_id  steps_taken  \
# 0      61  21     0    65.0    20.0        10      7642           29
# 1      64  15     0    65.0    20.0        19      5479           56
# 2      62  18     0    65.0    20.0        14      6560          827
# 3      66  19     0    65.0    20.0        17      6925           40
# 4      62  16     0    65.0    20.0        16      5838          638
# ...   ...  ..   ...     ...     ...       ...       ...          ...
# 1555  313  40    77   312.5    40.0       263     14753          318
# 1556  311  42    77   312.5    40.0       263     15473          380
# 1557  311  41    77   312.5    40.0       262     15112          360
# 1558  314  37    77   312.5    40.0       261     13671          372
# 1559  314  40    77   312.5    40.0       264     14754          319
#
#       extra_steps
# 0              19
# 1              37
# 2             813
# 3              23
# 4             622
# ...           ...
# ...

# %%
fig, ax = plt.subplots(figsize=(18,5))

ax.set_xlim(58,317)
ax.set_xticks(np.arange(60,321,10))
ax.set_ylim(10,50)
ax.set_yticks(np.arange(15,46,10))
ax.invert_yaxis()

ax.set_aspect('equal')

# Draw cells
added_legend = False
for y in range(15,45, 10):
    for x in range(60, 315, 10):
        if not added_legend:
            ax.add_patch(Rectangle([x, y], width=(10 if x+10 < 315 else 315-x), height=10, linewidth=1, edgecolor='black', facecolor='none', label='Cells'))
            added_legend = True
        else:
            ax.add_patch(Rectangle([x, y], width=(10 if x+10 < 315 else 315-x), height=10, linewidth=1, edgecolor='black', facecolor='none'))

ax.add_patch(Rectangle([60, 15], width=315-60, height=45-15, linewidth=2, edgecolor='b', facecolor='none', label='Cells'))

# Scatter starting points
ax.scatter(grid_test_df['x'].to_list(), grid_test_df['y'].to_list(), s=2, color='green', label='Starting points')

# Goal
ax.scatter(x=60, y=30, s=40, color='red', label='Source')

# Plot config
ax.set_xticks([])
ax.set_yticks([])

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

# ax.legend(loc='upper right')

# %% [markdown]
# # Run-3 perf

# %%
fig, ax = plt.subplots(1, figsize=(10,4))
im = plot_grid_extra_steps_from_file(folder + '/GridSimulations/Grid-run-3-1560sims.csv', ax=ax)
plt.colorbar(im, ax=ax, location='bottom', orientation='horizontal')

# %% [markdown]
# # Visualize extra steps

# %% [markdown]
# ## Ground only

# %%
# Saved as: perf_grid_var_ground.png
ground_file = './Test_Results/Test_Ground_fsvi_300it_100exp_099g_1e-06eps_20run_300sim_20231127_185934/grid_extra_steps.csv'
fig, ax = plt.subplots(figsize=(10,8))
plot_extra_steps_from_file(ground_file, ax=ax)

# %% [markdown]
# ## Ground and air

# %% [markdown]
# ### Test 11-21

# %%
file = folder + '/extra_steps.csv'
df = pd.read_csv(file)
if 'Average' in df:
    df = df.drop(columns='Average')

# Compute means and errors
medians = []
errors_low = []
errors_high = []
for i in range(20):
    m = np.median(df.iloc[i].to_numpy())
    medians.append(m)
    errors_low.append(m - np.percentile(df.iloc[i].to_numpy(), 20))
    errors_high.append(np.percentile(df.iloc[i].to_numpy(), 80) - m)
    

medians = np.array(medians)
errors = np.vstack([errors_low, errors_high])

# Plot error bars
plt.figure(figsize=(10,8))
plt.errorbar(np.arange(20)+1, medians, errors, fmt='o', color='black')

plt.xticks(np.arange(20)+1)
plt.xlabel('Solving Run', fontdict={'size':16})

plt.yticks([0,800])
plt.ylabel('Additional Steps to Target', labelpad=-10, fontdict={'size':16})
# Out:
# Text(0, 0.5, 'Additional Steps to Target')

# %%
file = folder + '/grid_extra_steps.csv'
df = pd.read_csv(file)
if 'Average' in df:
    df = df.drop(columns='Average')

# Compute means and errors
medians = []
errors_low = []
errors_high = []
for i in range(20):
    m = np.median(df.iloc[i].to_numpy())
    medians.append(m)
    errors_low.append(m - np.percentile(df.iloc[i].to_numpy(), 20))
    errors_high.append(np.percentile(df.iloc[i].to_numpy(), 80) - m)
    

medians = np.array(medians)
errors = np.vstack([errors_low, errors_high])

# Plot error bars
plt.figure(figsize=(10,8))
plt.errorbar(np.arange(20)+1, medians, errors, fmt='o', color='black')

plt.xticks(np.arange(20)+1)
plt.xlabel('Solving Run', fontdict={'size':16})

plt.yticks([0,800])
plt.ylabel('Additional Steps to Target', labelpad=-10, fontdict={'size':16})
# Out:
# Text(0, 0.5, 'Additional Steps to Target')

# %% [markdown]
# ## Comparing ground vs ground air averages

# %%
# Saved as: perf_grid_avg_comparison.png
ground_file = './Test_Results/Test_Ground_fsvi_300it_100exp_099g_1e-06eps_20run_300sim_20231127_185934/grid_extra_steps.csv'
groundair_file = './Test_Results/Test_GroundAir_FSVI_300it_100exp_099g_e6eps_20run_20231121_165329/grid_extra_steps.csv'

ground_df = pd.read_csv(ground_file)
groundair_df = pd.read_csv(groundair_file)

if 'Average' in ground_df:
    ground_df.drop(columns='Average', inplace=True)

if 'Average' in groundair_df:
    groundair_df.drop(columns='Average', inplace=True)

ground_averages = np.average(ground_df.to_numpy(), axis=1)
groundair_averages = np.average(groundair_df.to_numpy(), axis=1)

plt.boxplot([groundair_averages, ground_averages])
plt.xticks(np.arange(2)+1, ['Ground and Air', 'Ground Only'])
plt.ylabel('Average additional steps to target')
# Out:
# Text(0, 0.5, 'Average additional steps to target')

# %%
ground_file = './Test_Results/Test_Ground_fsvi_300it_100exp_099g_1e-06eps_20run_300sim_20231127_185934/grid_extra_steps.csv'
groundair_file = './Test_Results/Test_GroundAir_FSVI_300it_100exp_099g_e6eps_20run_20231121_165329/grid_extra_steps.csv'

ground_df = pd.read_csv(ground_file)
groundair_df = pd.read_csv(groundair_file)

if 'Average' in ground_df:
    ground_df.drop(columns='Average', inplace=True)

if 'Average' in groundair_df:
    groundair_df.drop(columns='Average', inplace=True)

ground_averages = np.average(ground_df.to_numpy(), axis=1)
groundair_averages = np.average(groundair_df.to_numpy(), axis=1)

plt.figure(figsize=(15,4))
plt.boxplot([ground_averages, groundair_averages], vert=False, widths=0.3)
plt.yticks(np.arange(2)+1, ['Ground Only', 'Ground and Air'])
plt.xlabel('Average additional steps to target')
# Out:
# Text(0.5, 0, 'Average additional steps to target')

# %% [markdown]
# ## Vertical wrap only ground and air

# %%
file = './Test_Results/Test_VertGroundAir_fsvi_300it_100exp_099g_1e-06eps_20run_300sim_20231125_230106/grid_extra_steps.csv'
plot_extra_steps_from_file(file)

# %% [markdown]
# ## Vertical wrap only ground only

# %%
file = './Test_Results/Test_VertGround_fsvi_300it_100exp_099g_1e-06eps_20run_300sim_20231125_230820/grid_extra_steps.csv'
plot_extra_steps_from_file(file)

# %% [markdown]
# ## Comparing ground vs ground air averages

# %%
vert_ground_file = './Test_Results/Test_VertGround_fsvi_300it_100exp_099g_1e-06eps_20run_300sim_20231125_230820/grid_extra_steps.csv'
vert_groundair_file = './Test_Results/Test_VertGroundAir_fsvi_300it_100exp_099g_1e-06eps_20run_300sim_20231125_230106/grid_extra_steps.csv'

vert_ground_df = pd.read_csv(vert_ground_file)
vert_groundair_df = pd.read_csv(vert_groundair_file)

if 'Average' in vert_ground_df:
    vert_ground_df.drop(columns='Average', inplace=True)

if 'Average' in vert_groundair_df:
    vert_groundair_df.drop(columns='Average', inplace=True)

vert_ground_averages = np.average(vert_ground_df.to_numpy(), axis=1)
vert_groundair_averages = np.average(vert_groundair_df.to_numpy(), axis=1)

plt.boxplot([vert_groundair_averages, vert_ground_averages])
plt.xticks(np.arange(2)+1, ['Ground and Air', 'Ground Only'])
plt.ylabel('Average additional steps to target')
# Out:
# Text(0, 0.5, 'Average additional steps to target')

# %% [markdown]
# ## All wrap or vert only ground and air

# %%
df = pd.DataFrame({'As in alternation paper': groundair_averages, 'Only vertical wrap allowed': vert_groundair_averages})

fig, ax = plt.subplots()
ax.set_title('Ground and air')
df.plot(kind='box', ax=ax)
plt.ylabel('Average additional steps to target')
# Out:
# Text(0, 0.5, 'Average additional steps to target')

# %%
df = pd.DataFrame({'As in alternation paper': ground_averages, 'Only vertical wrap allowed': vert_ground_averages})

fig, ax = plt.subplots()
ax.set_title('Ground only')
df.plot(kind='box', ax=ax)
plt.ylabel('Average additional steps to target')
# Out:
# Text(0, 0.5, 'Average additional steps to target')

# %% [markdown]
# ## Progress plot

# %%
averages_dict = {}
st_devs_dict = {}

# %%
longer_folder = 'C:/Users/arnau/Desktop/Master Thesis Files [TO BACKUP]/Test_LongerGroundAir_fsvi_600it_100exp_099g_1e-06eps_60run_0sim_20231127_154030'

# %%
# Longer process
prog_groundair_file = longer_folder + '/grid_extra_steps.csv'

prog_groundair_df = pd.read_csv(prog_groundair_file)

medians = np.median(np.array(prog_groundair_df), axis=1)
q1_dev = medians - np.percentile(np.array(prog_groundair_df), q=20, axis=1)
q3_dev = np.percentile(np.array(prog_groundair_df), q=80, axis=1) - medians

xs = np.arange(0,len(medians)*10,10)
fig, ax = plt.subplots(1, figsize=(15,8))
ax.errorbar(xs, medians, yerr=np.array([q1_dev, q3_dev]), fmt='-o', c='black')

ax.set_yticks([0,800])
ax.set_ylabel('Average additional steps to target', fontdict={'size':16}, labelpad=-20)

ax.set_xticks([0,200,400,600])
ax.set_xlabel('Training iteration', fontdict={'size':16}, labelpad=-10)

ax.tick_params(labelsize=14)

# %%
np.array([q1_dev, q3_dev]).shape
# Out:
# (2, 60)

# %%
averages_dict['ground_air'] = averages[:30]
st_devs_dict['ground_air'] = st_dev[:30]

# %%
files = {
    'ground': './Test_Results/Test_ProgGround_fsvi_300it_100exp_099g_1e-06eps_30run_300sim_20231126_010344/grid_extra_steps.csv',
    'vert_groundair': './Test_Results/Test_ProgVertGroundAir_fsvi_300it_100exp_099g_1e-06eps_30run_300sim_20231126_010553/grid_extra_steps.csv',
    'vert_ground': './Test_Results/Test_ProgVertGround_fsvi_300it_100exp_099g_1e-06eps_30run_300sim_20231126_010508/grid_extra_steps.csv',
}

for k, file in files.items():
    prog_df = pd.read_csv(file)

    averages = np.average(np.array(prog_df), axis=1)
    st_dev = np.std(np.array(prog_df), axis=1)

    averages_dict[k] = averages
    st_devs_dict[k] = st_dev

# %%
xs = np.arange(0, 300, 10)

i = 0
for k, v in averages_dict.items():
    if 'vert' in k:
        continue

    st_dev = st_devs_dict[k]
    plt.errorbar(xs + i, v, yerr=st_dev, fmt='-o', label=k)

    i += 1

plt.legend()
plt.ylabel('Average additional steps to target')
plt.xlabel('Training time')
# Out:
# Text(0.5, 0, 'Training time')

# %%
xs = np.arange(0, 300, 10)

i = 0
for k, v in averages_dict.items():
    if 'vert' not in k:
        continue

    st_dev = st_devs_dict[k]
    plt.errorbar(xs + i, v, yerr=st_dev, fmt='-o', label=k)

    i += 1

plt.legend()
plt.ylabel('Average additional steps to target')
plt.xlabel('Training time')
# Out:
# Text(0.5, 0, 'Training time')

# %% [markdown]
# # Run stats

# %%
stats_file = './Test_Results/Test_GroundAir_FSVI_300it_100exp_099g_e6eps_20run_20231121_165329/runs_stats.csv'
df = pd.read_csv(stats_file)

# %%
print(df.to_latex(index=False))
# Out:
# \begin{tabular}{rrrrr}
# \toprule
# run & avg_beliefs & time & alpha_vectors & iterations \\
# \midrule
# 0 & 84.760000 & 193.955800 & 7402 & 291 \\
# 1 & 82.020000 & 205.884400 & 7194 & 300 \\
# 2 & 85.260000 & 205.506500 & 7282 & 279 \\
# 3 & 84.240000 & 191.955500 & 6737 & 284 \\
# 4 & 85.870000 & 213.257800 & 7069 & 289 \\
# 5 & 85.260000 & 219.833000 & 7583 & 300 \\
# 6 & 85.560000 & 210.425300 & 7234 & 300 \\
# 7 & 85.080000 & 169.391100 & 6491 & 269 \\
# 8 & 80.220000 & 215.388000 & 7221 & 300 \\
# 9 & 82.200000 & 200.313100 & 7045 & 300 \\
# 10 & 83.150000 & 224.501800 & 7659 & 300 \\
# 11 & 83.760000 & 220.985300 & 7469 & 300 \\
# 12 & 85.030000 & 222.125700 & 7896 & 298 \\
# 13 & 86.510000 & 215.072200 & 7008 & 300 \\
# 14 & 86.220000 & 217.044000 & 7496 & 300 \\
# 15 & 84.390000 & 180.252400 & 6729 & 275 \\
# 16 & 87.540000 & 224.529700 & 7760 & 291 \\
# 17 & 82.350000 & 192.362900 & 7018 & 286 \\
# 18 & 82.400000 & 191.910100 & 6913 & 276 \\
# ...

# %% [markdown]
# # Grid performance plots

# %%
grid_sim_folder = './Test_Results/Test_GroundAir_FSVI_300it_100exp_099g_e6eps_20run_20231121_165329/GridSimulations/'

# %%
fig, axes = plt.subplots(10,2, figsize=(15,15))

for i in range(20):
    ax = axes[i%10, int(i/10)]
    ax.set_title(f'Run-{i}')
    im = plot_grid_extra_steps_from_file(grid_sim_folder + f'Grid-run-{i}-1560sims.csv', vmax=800, ax=ax)

cax,kw = mpl.colorbar.make_axes([ax for ax in axes.flat])
cbar = plt.colorbar(im, cax=cax)
cbar.set_label('Additional steps to target')

# %%
fig, axes = plt.subplots(3,1, figsize=(17,8))

grid_sim_folder = folder + '/GridSimulations/'

for i, run_i in enumerate([0,9,16]):
    ax = axes[i]
    ax.set_title(f'Run-{run_i}', fontdict={'size':16})

    points_df = pd.read_csv(grid_sim_folder + f'Grid-run-{run_i}-1560sims.csv')
    vmax = 500

    average_per_cell = points_df.groupby('cell').mean('extra_steps')['extra_steps'].to_list()
    cell_xs = pd.unique(points_df['cell_x'])
    cell_ys = pd.unique(points_df['cell_y'])

    average_grid = []
    item = 0
    for _ in cell_ys:
        row = []
        for _ in cell_xs:
            row.append(average_per_cell[item])
            item += 1
        average_grid.append(row)
    average_grid_array = np.array(average_grid)

    # Actual plot
    if ax is None:
        _, ax = plt.subplots()

    im = ax.imshow(average_grid_array, cmap=mpl.colormaps['RdYlGn'].reversed(), vmin=0, vmax=(np.max(average_grid_array) if vmax is None else vmax))
    # plt.colorbar(im, orientation='horizontal', ax=ax)

    # Axes
    ax.set_xticks([])
    ax.set_yticks([])
    # ax.set_xticks(np.arange(average_grid_array.shape[1]), labels=cell_xs.astype(int), rotation=90)
    # ax.set_yticks(np.arange(average_grid_array.shape[0]), labels=cell_ys.astype(int))

    # im = plot_grid_extra_steps_from_file(grid_sim_folder + f'Grid-run-{run_i}-1560sims.csv', vmax=500, ax=ax)

cax,kw = mpl.colorbar.make_axes([ax for ax in axes.flat])
cbar = plt.colorbar(im, cax=cax, ticks=[0,500])
cbar.set_label('Additional steps to target', labelpad=-20, fontdict={'size':16})
cbar.ax.tick_params(labelsize=14)
# plt.subplots_adjust(hspace=0.5)

# %% [markdown]
# # All runs paths

# %%
def path_plot_ax(sim_hist, ax, legend=False):
    # Get cpu model
    model = sim_hist.model.cpu_model

    # Plot setup
    env_shape = model.cpu_model.state_grid.shape
    ax.set_xlim(0, env_shape[1])
    ax.set_ylim(env_shape[0], 0)

    # Start
    start_coord = sim_hist.grid_point_sequence[0]
    ax.scatter(start_coord[1], start_coord[0], c='green', label='Start')

    # Goal
    goal_coord = np.array([np.argwhere(model.state_grid == g)[0].tolist() for g in model.end_states])
    ax.scatter(goal_coord[:,1], goal_coord[:,0], c='red', label='Goal')

    # Path
    seq = np.array(sim_hist.grid_point_sequence)
    ax.plot(seq[:,1], seq[:,0], zorder=-1, c='black', label='Path')

    # Something sensed
    something_obs_id = model.observation_labels.index('something')
    obs_ts = np.where(np.array(sim_hist.observations) == something_obs_id)
    points_obs = seq[obs_ts[0],:]
    ax.scatter(points_obs[:,1], points_obs[:,0], zorder=1, label='Something observed')

    # Points sniff
    sniff_air_action_id = -1
    for i, al in enumerate(model.action_labels):
        if 'air' in al.lower():
            sniff_air_action_id = i
    sniff_in_air = np.where(np.array(sim_hist.actions) == sniff_air_action_id)
    points_sniff = seq[sniff_in_air[0],:]
    if len(points_sniff) > 0:
        ax.scatter(points_sniff[:,1], points_sniff[:,0], zorder=2, marker='x', label='Sniff in the air')

    ax.set_aspect('equal')

    # Generate legend
    if legend:
        ax.legend()

# %%
model = Model.load_from_file('./Models/Alt_Wrap_GroundAir.pck')

# %%
ground_air_test_folder = './Test_Results/Test_GroundAir_FSVI_300it_100exp_099g_e6eps_20run_20231121_165329/'

steps_count = 500
run_sims = []

for i in range(20):
    simulations_df = pd.read_csv(ground_air_test_folder + f'Simulations/run-{i}-sims.csv', index_col=0)

    for col in simulations_df.columns:
        sim_steps = simulations_df[col].tolist()
        sim_steps = [json.loads(step) for step in sim_steps if isinstance(step, str)]

        # Creation of simulation history
        sim_hist = SimulationHistory(model, sim_steps[0]['s'], Belief(model))

        sim_hist.states = [step['s'] for step in sim_steps][:steps_count]
        sim_hist.actions = [step['a'] for step in sim_steps][:steps_count-1]
        sim_hist.observations = [step['o'] for step in sim_steps][:steps_count-1]
        sim_hist.rewards = [step['r'] for step in sim_steps][:steps_count-1]

        # Adding it to set
        run_sims.append(sim_hist)

        break

# %%
fig, axes = plt.subplots(10,2, figsize=(20,25))

for i in range(20):
    ax.set_title(f'Run-{i}')
    ax = axes[i%10, int(i/10)]
    path_plot_ax(run_sims[i], ax, i==10)

# %% [markdown]
# # Runtimes plots

# %%
runtimes_df = pd.read_csv('./Test_Results/Test_GroundAir_FSVI_300it_100exp_099g_e6eps_20run_20231121_165329/single_run_stats.csv')
